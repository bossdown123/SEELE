# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from keras.models import *
from tensorflow.keras.layers import *
from keras.optimizers import *

# %%
import yfinance as yf
import pickle as pkl
yf.Ticker('AAPL').history(period='1d', interval='1m')
from utils import *
with open('multi_scaler.pickle','rb') as f:
    multi_scaler=pkl.load(f)

# %%
if set(multi_scaler.scalers[0]['procedures'][0].get_feature_names_out()).intersection(set(['symbol'])):
    print(1)

# %%
model.predict(np.ones((1, 26, 4)))
# Out:
# 1/1 [==============================] - 0s 25ms/step
# array([[0.3493041, 0.6482169]], dtype=float32)

# %%
a=[{"T":"b","S":"AAPL","o":169.58,"h":169.5998,"l":169.41,"c":169.451,"v":94932,"t":"2024-04-16T17:15:00Z","n":1042,"vw":169.505447}]
b=[{"T":"b","S":"TSLA","o":157.48,"h":157.5,"l":157.17,"c":157.2046,"v":190500,"t":"2024-04-16T17:15:00Z","n":1670,"vw":157.299385}]
c=[{"T":"b","S":"AAPL","o":169.455,"h":169.57,"l":169.455,"c":169.56,"v":57510,"t":"2024-04-16T17:16:00Z","n":773,"vw":169.502856}]
from supabase import create_client
from supabase.client import Client
url: str = "https://yygimsahwbrurnvyfmul.supabase.co"
key: str = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Inl5Z2ltc2Fod2JydXJudnlmbXVsIiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTcxMDY4ODI2OCwiZXhwIjoyMDI2MjY0MjY4fQ.A0EiE0m1Ze_bYOz-8LBymdBwHvQwMr3n0wO6ajvJtzw"
supabase: Client = create_client(url, key)

# %%
supabase.table('DataStream').upsert(a).execute()
# Out:
# 2024-04-16 17:23:04,917:INFO - HTTP Request: POST https://yygimsahwbrurnvyfmul.supabase.co/rest/v1/DataStream?columns=%22h%22%2C%22T%22%2C%22c%22%2C%22l%22%2C%22vw%22%2C%22v%22%2C%22n%22%2C%22t%22%2C%22S%22%2C%22o%22 "HTTP/1.1 201 Created"
# APIResponse[~_ReturnT](data=[{'S': 'AAPL', 'o': 169.58, 'h': 169.6, 'l': 169.41, 'c': 169.451, 'v': 94932, 't': '2024-04-16T17:15:00+00:00', 'n': 1042, 'vw': 169.505, 'T': 'b'}], count=None)

# %%
from datetime import *
def get_bars(symbol_or_symbols,time):
    start_time=time-timedelta(days=4)
    request_params=StockBarsRequest(
        symbol_or_symbols=symbol_or_symbols,
        start=start_time,
        end=time,
        timeframe=TimeFrame(15,TimeFrameUnit('Min')),
        adjustment=Adjustment.ALL,
        feed='sip'
        )
    return client.get_stock_bars(request_params).df
barset=get_bars(['AAPL'],datetime.now()).loc['AAPL']
#print(barset)
barset.columns=['o','h','l','c','v','n','vw']
barset.index.name='t'
barset['n'] = barset['n'].astype(int)
barset['v'] = barset['v'].astype(int)
barset['S'] ='AAPL'
barset.reset_index(inplace=True)
barset['t']=barset['t'].apply(lambda x:x.strftime('%Y-%m-%dT%H:%M:%SZ'))
supabase.table('DataStream').upsert(barset.to_dict(orient='records')).execute()
# Out:
# 2024-04-16 19:53:10,295:INFO - HTTP Request: POST https://yygimsahwbrurnvyfmul.supabase.co/rest/v1/DataStream?columns=%22h%22%2C%22c%22%2C%22l%22%2C%22vw%22%2C%22v%22%2C%22n%22%2C%22t%22%2C%22S%22%2C%22o%22 "HTTP/1.1 201 Created"
# ...

# %%
barset.to_dict(orient='records')[20].
# Out:
# {'t': Timestamp('2024-04-15 09:45:00+0000', tz='UTC'),
#  'o': 175.15,
#  'h': 175.18,
#  'l': 174.5,
#  'c': 174.65,
#  'v': 11991,
#  'n': 288,
#  'vw': 174.740087,
#  'S': 'AAPL'}

# %%
a="{'columns': [{'name': 'S', 'type': 'varchar'}, {'name': 'o', 'type': 'float4'}, {'name': 'h', 'type': 'float4'}, {'name': 'l', 'type': 'float4'}, {'name': 'c', 'type': 'float4'}, {'name': 'v', 'type': 'int4'}, {'name': 't', 'type': 'timestamptz'}, {'name': 'n', 'type': 'int4'}, {'name': 'vw', 'type': 'float4'}, {'name': 'T', 'type': 'WsType'}], 'commit_timestamp': '2024-04-17T11:52:00.614Z', 'errors': None, 'record': {'S': 'AAPL', 'T': None, 'c': 169.79, 'h': 169.82, 'l': 169.71, 'n': 138, 'o': 169.71, 't': '2024-04-17T11:45:00+00:00', 'v': 4693, 'vw': 169.792}, 'schema': 'public', 'table': 'DataStream', 'type': 'INSERT'}"

# %%
pydantic.

# %%
# !pip install pydantic
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
